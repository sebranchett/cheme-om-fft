# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from scipy.fft import fft, fftfreq
from pytest import approx

# %%
experiment = "MOS2_150uW_9K"
# experiment = "GaAs_50uW_rt"

# %%
def plot_my_freq_array(freqs, complex_array, half=False):
    N = len(freqs)
    if half:
        last = N//2
    else:
        last = N
    plt.plot(freqs[0:last], np.real(complex_array)[0:last], label='real')
    plt.plot(freqs[0:last], -1.0 * np.imag(complex_array)[0:last], label='imag')
    plt.plot(freqs[0:last], np.abs(complex_array)[0:last], label='abs')
    plt.legend()
    plt.grid()
    plt.show()

# %%
ref = np.loadtxt(fname='data/'+experiment+'_TDS.txt', delimiter=' ')[:500]

plt.ylim((-500, 3500))
for col in range(1, ref.shape[1]):
    plt.plot(ref[:, 0], ref[:, col], label=str(col))
plt.legend()
plt.grid()

# %%
sample = np.loadtxt(fname='data/'+experiment+'_TRTS.txt', delimiter=' ')[:500]

plt.ylim((-500, 3500))
for col in range(1, sample.shape[1]):
    plt.plot(sample[:, 0], sample[:, col], label=str(col))
plt.legend()
plt.grid()

# %%
# Do some tests to make sure what we are dealing with

# Sample and reference should have the same time steps
assert sample[:, 0].all() == approx(ref[:, 0].all())  # we're dealing with reals

# The time steps must be evenly distributed
T = sample[1, 0] - sample[0, 0]
for i in range(1, len(sample)):
    assert T == approx(sample[i, 0] - sample[i-1, 0])

# %%
plt.ylim((2960, 2980))
plt.plot(ref[:, 0], ref[:, 2], label='ref'+str(2))
plt.plot(sample[:, 0], sample[:, 2], label='sample'+str(2))
plt.legend()
plt.grid()

# %%
# plt.ylim((2960, 2980))
# plt.xlim((-2e-12, 2e-12))
plt.plot(ref[:, 0], ref[:, 2] - ref[:, 1] - (sample[:, 2] - sample[:, 1]))
#plt.legend()
plt.grid()

# %%
# plt.ylim((250, 1000))
plt.xlim((-2e-12, 0))
plt.plot(ref[:, 0], ref[:, 2] - ref[:, 1], label="ref")
plt.plot(ref[:, 0], sample[:, 2] - sample[:, 1], label="sample")
plt.legend()
plt.grid()

# %%
# plt.ylim((1350, 1500))
plt.xlim((-0.4e-12, 0.4e-12))
plt.plot(ref[:, 0], ref[:, 2] - ref[:, 1], 'b', label="ref")
plt.plot(ref[:, 0], sample[:, 2] - sample[:, 1], 'r', label="sample")
plt.legend()
plt.grid()
plt.title(experiment)

plt.savefig(experiment+'.png')

# %%
s2ms1_ref = ref[:, 2] - ref[:, 1]
s2ms1_sample = sample[:, 2] - sample[:, 1]

# %%
# Find the frequencies
T = ref[1, 0] - ref[0, 0]
N = len(ref[:, 0])
xf = fftfreq(N, T)

# %%
# Find the FT for ref
E_ref = fft(s2ms1_ref)
plt.xlim(0., 4e12)
plot_my_freq_array(xf, E_ref, half=True)

# %%
# Find the FT for sample
E_sample = fft(s2ms1_sample)
plt.xlim(0., 4e12)
plot_my_freq_array(xf, E_sample, half=True)

# %%
im_array = (E_ref - E_sample)/E_sample

plt.xlim((0, 2.7e12))
plt.ylim((-0.005, .005))
plot_my_freq_array(xf, im_array, half=True)

# %%
from scipy.signal import blackman
w = blackman(N)
E_ref_w = fft(s2ms1_ref*w)
E_sample_w = fft(s2ms1_sample*w)

im_array_w = (E_ref_w - E_sample_w)/E_sample_w

plt.xlim((0, 2.7e12))
plt.ylim((-0.004, .004))
plt.plot(xf[1:N//2], np.real(im_array[1:N//2]), '-b', label='real no window')
plt.plot(xf[1:N//2], np.real(im_array_w[1:N//2]), '-r', label='real window')
plt.legend()
plt.grid()
plt.show()

# %%
plt.xlim((0, 2.7e12))
plt.ylim((-0.004, .004))
plt.plot(xf[1:N//2], np.imag(im_array[1:N//2]), '-b', label='imag no window')
plt.plot(xf[1:N//2], np.imag(im_array_w[1:N//2]), '-r', label='imag window')
plt.legend()
plt.grid()
plt.show()
